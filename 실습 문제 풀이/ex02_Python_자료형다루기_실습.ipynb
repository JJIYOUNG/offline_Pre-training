# %% [markdown]
# #### 1. 삼행시 짓기
# print("출력할 내용")를 이용하면 원하는 내용을 출력할 수 있습니다. 이를 활용하여 삼행시를 지어 봅시다.
#  - 키워드:<br>
#  무<br>
#  지<br>
#  개

# %%
print("무등산에\n지금\n개나리가 폈어요!")

# print("""무등산에
# 지금
# 개나리가 폈어요!""")
# Out:
# 무등산에
# 지금
# 개나리가 폈어요!

# %% [markdown]
# #### 2. 거꾸로 계산기
# 숫자형 연산 중에서는 몫을 구하는 연산자(//), 나머지를 구하는 연산자(%), 거듭제곱(**)을 구하는 연산자가 있습니다.
# <br>
# 우리가 원하는 값을 알고 있을때, //, %, **을 이용해서 이 값이 나오는 수식을 작성해봅시다.

# %%
# //을 이용해서 변수 intdiv에 4를 넣는 수식을 작성해봅시다.
intdiv = 16//4

# %을 이용해서 변수 modular에 1을 넣는 수식을 작성해봅시다.
modular = 15%7

# **을 이용해서 변수 expo에 16을 넣는 수식을 작성해봅시다.
expo = 2**4

#위의 세 변수를 출력해서 확인해봅시다.
print(intdiv, modular, expo)
# Out:
# 4 1 16

# %% [markdown]
# #### 3.날씨 데이터에서 원하는 정보만 추출하기!
# 기상자료개방포털 에서는 지역별 날씨 정보를 제공하고 있습니다.
# <br>
# 다음 예시와 같이 2023년 3월의 서울과 제주의 날씨 정보를 가져와서 파이썬 리스트로 저장하였습니다.

# %%
# 3월 서울의 날씨는 다음과 같습니다.
seoul = ['8_맑음', '9_맑음', '10_흐리고 비', '11_맑음', '12_맑음', '13_맑음', '14_맑음', '15_맑음']

# 10일의 날씨 정보만 추출하여 아래 변수에 넣어봅시다!
seoul_rain = seoul[2]

# 제주 날씨는 다음과 같습니다.
jeju = ['8_맑음', '9_맑음', '10_맑음', '11_맑음', '12_흐리고 비', '13_흐리고 비', '14_흐리고 비', '15_맑음', '16_맑음', '17_맑음']

# 12일부터 14일까지의 날씨 정보들을 추출하여 아래 변수에 넣어봅시다!
jeju_rain = jeju[4:7]

# 여러분이 추출한 날씨 정보를 print()를 이용해서 한번 확인해보세요!
print('서울에서 비가 오는 날씨는 ', seoul_rain)
print('제주에서 비가 오는 날씨는 ', jeju_rain)
# Out:
# 서울에서 비가 오는 날씨는  10_흐리고 비
# 제주에서 비가 오는 날씨는  ['12_흐리고 비', '13_흐리고 비', '14_흐리고 비']

# %% [markdown]
# #### 실행시점의 현재시간(시,분)을 각각 hour, minute 변수에 대입하고 출력문을 완성하시오.
#
# - datetime 라이브러리를 활용하기
# - 출력결과>> <br>
#   - 실행 당시 현재 시간은 15시 34분 입니다.<br>

# %%
from datetime import datetime
from pytz import timezone

now_time = datetime.now(timezone('Asia/Seoul'))
print(now_time)
print(now_time.hour)
print(now_time.minute)
# Out:
# 2024-03-27 10:44:36.167168+09:00
# 10
# 44

# %%
hour = now_time.hour
minute = now_time.minute
print(f'실행 당시 현재 시간은 {hour}시 {minute}분 입니다.')
# Out:
# 실행 당시 현재 시간은 10시 44분 입니다.

# %% [markdown]
# #### 5. 섭씨를 화씨로 변환해봅시다!
# 우리나라는 온도의 단위가 섭씨(℃)인 반면, 미국에서는 화씨(℉)를 사용합니다. 이 둘 사이의 관계는 다음과 같습니다.<br>
#  - ℉는 화씨, ℃는 섭씨<br>
#    [℉] = [℃] * (9/5) + 32<br>
#    ex) 68℉ = 20℃ * (9/5) + 32<br>
# 온도는 숫자이기 때문에, 우리가 배운 숫자의 사칙연산으로 섭씨를 화씨로 변환할 수 있습니다!

# %%
#섭씨온도를 담을 변수 c를 선언하고, 숫자 18을 담아봅시다.
c = 18

#화씨온도를 담을 변수 f를 선언하고, c와 섭씨-화씨 변환식을 이용해서 값을 담아봅시다.
f = c *(9/5)+32

#변수 today_temp를 선언하고, 섭씨온도 c와 화씨온도 f를 순서대로 담은 리스트를 담아봅시다.
today_temp = [c, f]

#맞게 변환했는지 today_temp를 print()로 확인해봅시다.
print(today_temp)
# Out:
# [18, 64.4]

# %% [markdown]
# #### 6.article 문자열에 있는 기사입력 일자를 인덱스 번호를 이용하여 추출하고 다음과 같이 출력하시오.
#
# - 출력결과 >>
#   - 기사가 업로드된 일자는 2023.03.10. 입니다.

# %%
article = "[요기요, 화이트데이 맞이 '선물하기' 이벤트 진행] 기사입력 2023.03.10. 작성자 이나영기자 요기요는 화이트데이를 앞두고 요기요 선물하기 서비스를 이용하는 고객들을 위한 '너와 나의 선물고리' 이벤트를 진행한다고 10일 밝혔다."
start_idx = article.find('2023')
end_idx = article.find(' 작성자')
print(start_idx, end_idx)
upload_date = article[start_idx:end_idx]
print(f'기사가 업로드된 일자는 {upload_date} 입니다.')
# Out:
# 35 46
# 기사가 업로드된 일자는 2023.03.10. 입니다.

# %% [markdown]
# #### 7. 콤마(,)로 구분된 한국음식 문자열 foods가 주어졌다. 몇개의 한국 음식이 들어있을까?
#
# - 음식들을 food_list 리스트 변수에 담은 다음, 리스트의 길이를 확인하기

# %%
foods = "설렁탕,찐만두,설렁탕,오이지,팥(시루)떡,산적,미역무침,미삼무침,밑반찬,고추,깻잎부각,낙지회,소주,갈비구이,고명,전골,오징어덮밥,(무)비늘김치,짠무,율무차,토란국,오징어회,두릅전,안동찜닭,송이밥,딸기,명란찜,곰국수,생강정과,더덕장아찌,섞박지,젓국찌개,한치회덮밥,파,문배주,버섯,백김치,안동소주,오분자기,씀바귀나물(생채),쇠머리편육,조개국수,대합찜,정과,백반,오징어숙회,회냉면,녹두빈대떡,김치볶음밥,사태찜,찰밥"

food_list = foods.split(",")
print(food_list)

print(len(food_list))
# Out:
# ['설렁탕', '찐만두', '설렁탕', '오이지', '팥(시루)떡', '산적', '미역무침', '미삼무침', '밑반찬', '고추', '깻잎부각', '낙지회', '소주', '갈비구이', '고명', '전골', '오징어덮밥', '(무)비늘김치', '짠무', '율무차', '토란국', '오징어회', '두릅전', '안동찜닭', '송이밥', '딸기', '명란찜', '곰국수', '생강정과', '더덕장아찌', '섞박지', '젓국찌개', '한치회덮밥', '파', '문배주', '버섯', '백김치', '안동소주', '오분자기', '씀바귀나물(생채)', '쇠머리편육', '조개국수', '대합찜', '정과', '백반', '오징어숙회', '회냉면', '녹두빈대떡', '김치볶음밥', '사태찜', '찰밥']
# 51

# %% [markdown]
# #### 8. 딕셔너리에 내 짝꿍의 정보가 들어있다. 무슨 일인지 정보가 잘못 들어가져 있는데, 올바른 정보로 내용을 수정해보자! 마지막으로 딕셔너리 정보를 이용해서 친구를 소개하는 문구를 출력해보자!
#
# - 이름: 손지영
# - 나이: 32
# - 취미: 데이터 분석
# - 출력결과 >>
# 내 짝꿍을 소개할게! 이름은 손지영이고, 나이는 32, 취미는 데이터 분석이야!

# %%
partner = {"이름":"손지연", "나이":"320", "취미":"데이터 분석"}
partner

partner['이름'] = "손지영"
partner['나이'] = 32
print(f"내 짝꿍을 소개할게! 이름은 {partner['이름']}이고, 나이는 {partner['나이']}, 취미는 {partner['취미']}이야!")
# Out:
# 내 짝꿍을 소개할게! 이름은 손지영이고, 나이는 32, 취미는 데이터 분석이야!
